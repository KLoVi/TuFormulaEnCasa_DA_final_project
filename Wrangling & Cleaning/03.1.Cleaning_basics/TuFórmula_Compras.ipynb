# %%
import pandas as pd
import numpy as np

# %%
url = "/Users/karollvivianalopezvillegas/GitHub/OKVET_DA_Final_project/02_Datasets_pre_cleaning/TuFórmula_Compras.xlsx"

# %%
df = pd.read_excel(url)

# %%
df.shape
# Out:
# (171, 10)

# %%
df.head() # ACCIONES: Columnas a eliminar: Factura ; convetir "CANTIDAD" y "UNIDAD"" a Integer
# Out:
#                                     PRODUCTO FECHA COMPRA  \
# 0                Cardial B 5ml (comprimidos)   2024-02-06
# 1  Lata I/D Hill's pollo y vegetales 12.5 OZ   2024-02-06
# 2             Cosequin 60 felino (gominolas)   2024-02-07
# 3                   Acar clean 400ml (spray)   2024-02-10
# 4                Cefalexina 500mg (tabletas)   2024-02-10
#
#                      PROVEEDOR      FACTURA  CANTIDAD    COSTO  IVA  \
# 0               Gabrica S.A.S.    MED325011       3.0  93480.0  0.0
# 1               Gabrica S.A.S.    MED325011       1.0  57855.0  0.0
# 2              Andrés Cosequin   0000099600       1.0  99000.0  0.0
# 3       Almacenes Éxito S.A.S.  GA011002560       1.0  38200.0  0.0
# 4  Droguería Específica S.A.S.       796325       1.0  56000.0  0.0
#
#    COSTO TOTAL  UNIDAD  COSTO UNIDAD
# 0     280440.0     3.0      93480.00
# 1      57855.0     4.0      14463.75
# 2      99000.0     1.0      99000.00
# 3      38200.0     1.0      38200.00
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 171 entries, 0 to 170
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   PRODUCTO      171 non-null    object
#  1   FECHA COMPRA  171 non-null    datetime64[ns]
#  2   PROVEEDOR     171 non-null    object
#  3   FACTURA       163 non-null    object
#  4   CANTIDAD      170 non-null    float64
#  5   COSTO         170 non-null    float64
#  6   IVA           170 non-null    float64
#  7   COSTO TOTAL   170 non-null    float64
#  8   UNIDAD        170 non-null    float64
#  9   COSTO UNIDAD  170 non-null    float64
# dtypes: datetime64[ns](1), float64(6), object(3)
# memory usage: 13.5+ KB

# %%
df.isna().sum()
# Out:
# PRODUCTO        0
# FECHA COMPRA    0
# PROVEEDOR       0
# FACTURA         8
# CANTIDAD        1
# COSTO           1
# IVA             1
# COSTO TOTAL     1
# UNIDAD          1
# COSTO UNIDAD    1
# dtype: int64

# %%
df.nunique()
# Out:
# PRODUCTO        109
# FECHA COMPRA     56
# PROVEEDOR        23
# FACTURA          88
# CANTIDAD          5
# COSTO           123
# IVA               7
# COSTO TOTAL     134
# UNIDAD           14
# COSTO UNIDAD    133
# dtype: int64

# %%
df.drop(columns = "FACTURA", inplace = True)

# %%
df.head()
# Out:
#                                     PRODUCTO FECHA COMPRA  \
# 0                Cardial B 5ml (comprimidos)   2024-02-06
# 1  Lata I/D Hill's pollo y vegetales 12.5 OZ   2024-02-06
# 2             Cosequin 60 felino (gominolas)   2024-02-07
# 3                   Acar clean 400ml (spray)   2024-02-10
# 4                Cefalexina 500mg (tabletas)   2024-02-10
#
#                      PROVEEDOR  CANTIDAD    COSTO  IVA  COSTO TOTAL  UNIDAD  \
# 0               Gabrica S.A.S.       3.0  93480.0  0.0     280440.0     3.0
# 1               Gabrica S.A.S.       1.0  57855.0  0.0      57855.0     4.0
# 2              Andrés Cosequin       1.0  99000.0  0.0      99000.0     1.0
# 3       Almacenes Éxito S.A.S.       1.0  38200.0  0.0      38200.0     1.0
# 4  Droguería Específica S.A.S.       1.0  56000.0  0.0      56000.0    10.0
#
#    COSTO UNIDAD
# 0      93480.00
# 1      14463.75
# 2      99000.00
# 3      38200.00
# 4       5600.00

# %%
df.dropna(subset = ["CANTIDAD", "UNIDAD"], inplace = True)

# %%
df
# Out:
#                                              PRODUCTO FECHA COMPRA  \
# 0                         Cardial B 5ml (comprimidos)   2024-02-06
# 1           Lata I/D Hill's pollo y vegetales 12.5 OZ   2024-02-06
# 2                      Cosequin 60 felino (gominolas)   2024-02-07
# 3                            Acar clean 400ml (spray)   2024-02-10
# 4                         Cefalexina 500mg (tabletas)   2024-02-10
# ..                                                ...          ...
# 166     Nexgard Spectra 7,5 a 15kg (38/bmg) (tableta)   2024-06-26
# 167                                 Fórmula Magistral   2024-06-27
# 168                Thyro tabs 0,2mg 120tab (tabletas)   2024-06-27
# 169  Amoxicilina + acido clavulanico (nicilan) 500 mg   2024-06-29
# 170                      Previcox 227mg (comprimidos)   2024-06-29
#
#                                    PROVEEDOR  CANTIDAD    COSTO  IVA  \
# 0                             Gabrica S.A.S.       3.0  93480.0  0.0
# ...

# %%
df["UNIDAD"] = df["UNIDAD"].astype(int)

# %%
df["CANTIDAD"] = df["CANTIDAD"].astype(int)

# %%
df.dtypes
# Out:
# PRODUCTO                object
# FECHA COMPRA    datetime64[ns]
# PROVEEDOR               object
# CANTIDAD                 int64
# COSTO                  float64
# IVA                    float64
# COSTO TOTAL            float64
# UNIDAD                   int64
# COSTO UNIDAD           float64
# dtype: object

# %%
# df.to_excel("/Users/karollvivianalopezvillegas/GitHub/OKVET_DA_Final_project/04_Datasets_final/df_TuFórmula_Compras.xlsx", index = False)
