# %%
import pandas as pd

# %%
compras = "/Users/karollvivianalopezvillegas/GitHub/OKVET_DA_Final_project/04_Datasets_final/Datases_mod to merge/Copia de df_TuFórmula_Compras.xlsx"

# %%
ventas = "/Users/karollvivianalopezvillegas/GitHub/OKVET_DA_Final_project/04_Datasets_final/Datases_mod to merge/Copia de df_TuFórmula_Ventas.xlsx"

# %%
fórmulas = "/Users/karollvivianalopezvillegas/GitHub/OKVET_DA_Final_project/04_Datasets_final/Datases_mod to merge/Copia de df_OKVET_Fórmulas_80 final_Modificado to merge.xlsx"

# %%
df_compras = pd.read_excel(compras)

# %%
df_ventas = pd.read_excel(ventas)

# %%
df_fórmulas = pd.read_excel(fórmulas)

# %%
df_compras.head(1)
# Out:
#   Product_cat          PRODUCTO_modificado      FECHA       PROVEEDOR  \
# 0      Bought  Cardial B 5ml (comprimidos) 2024-02-06  Gabrica S.A.S.
#
#    CANTIDAD  COSTO TOTAL  UNIDAD (QTY)  COSTO UNIDAD
# 0         3     280440.0             3       93480.0

# %%
df_ventas.head(1)
# Out:
#   Product_cat          PRODUCTO_modificado      FECHA  UNIDAD (QTY)  \
# 0        Sold  Cardial B 5ml (comprimidos) 2024-02-06             1
#
#    PRECIO UNIDAD  PRECIO TOTAL         Autor
# 0         135000        135000  Paula Bernal

# %%
df_fórmulas.head(1)
# Out:
#                               key Product_cat       PRODUCTO_modificado  \
# 0  GUARDIANA_Sandra Milena galvis  Prescribed  Acar clean 400ml (spray)
#
#                                          Medicamento TuFórmula?  \
# 0  Nombre: gastricumeelPresentación: tabletasCant...  TuFórmula
#
#    medicamento_num   Paciente               Cliente Especie       Raza  \
# 0                8  GUARDIANA  Sandra Milena galvis  Canino  Dobermann
#
#    Género   E.Reproductivo      FECHA      Fecha registro       Fecha edición  \
# 0  Hembra  No esterilizado 2024-02-09 2024-02-09 10:10:45 2024-02-09 10:10:45
#
#                         Autor Fecha nacimiento
# 0  Paula  Andrea Bernal Yepes       2023-01-27

# %%
df_merged = pd.concat([df_fórmulas,df_compras,df_ventas])

# %%
df_merged
# Out:
#                                 key Product_cat  \
# 0    GUARDIANA_Sandra Milena galvis  Prescribed
# 1              Kuro_Natalia Salazar  Prescribed
# 2                mechas_paola marin  Prescribed
# 3       VALENTINO_DANIELA JARAMILLO  Prescribed
# 4              Thor_Juliana Castaño  Prescribed
# ..                              ...         ...
# 145                             NaN        Sold
# 146                             NaN        Sold
# 147                             NaN        Sold
# 148                             NaN        Sold
# 149                             NaN        Sold
#
#                                    PRODUCTO_modificado  \
# 0                             Acar clean 400ml (spray)
# 1                             Acar clean 400ml (spray)
# 2                                    Aceite de Girasol
# 3                Acetaminofen tabletas 500mg (tableta)
# 4                Acetaminofen tabletas 500mg (tableta)
# ...

# %%
#df_merged.to_excel("/Users/karollvivianalopezvillegas/GitHub/OKVET_DA_Final_project/04_Datasets_final/Datases_mod to merge/Merge_OKVET_Fórmulas & TuFórmula_compras_ventas.xlsx")

# %%
# NOTA: al emplear df_merged en Tableau... me di cuenta de algunos errores de clasificación de mendicamentos
# con relación a si es "Tu Fórmula" o no están disponibles.
